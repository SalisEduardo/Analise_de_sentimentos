# %%
import json
import matplotlib.pyplot as plt
import pandas as pd
import snscrape.modules.twitter as sntwitter
import itertools

# %%
search = "'Ambev' near:'Brazil' since:2019-01-01 until:2021-11-22"

# the scraped tweets, this is a generator
scraped_tweets = sntwitter.TwitterSearchScraper(search).get_items()

# %%
# slicing the generator to keep only the first 100 tweets
sliced_scraped_tweets = itertools.islice(scraped_tweets, 20000)

# convert to a DataFrame and keep only relevant columns
df = pd.DataFrame(sliced_scraped_tweets)[['date', 'content']]

# %%
df
# Out:
#                            date  \
# 0     2021-11-21 20:06:44+00:00
# 1     2021-11-21 19:35:28+00:00
# 2     2021-11-21 17:07:37+00:00
# 3     2021-11-21 15:58:06+00:00
# 4     2021-11-21 02:31:07+00:00
# ...                         ...
# 19995 2019-07-13 16:10:31+00:00
# 19996 2019-07-13 15:37:50+00:00
# 19997 2019-07-13 15:17:22+00:00
# 19998 2019-07-13 14:32:58+00:00
# 19999 2019-07-13 13:14:14+00:00
#
#                                                  content
# 0      I'm at Ambev - CDD Bebedouro https://t.co/Sy5f...
# 1      Todo nicolas cagevannuccinho @ambev @brahmacer...
# 2      Depois de ontem se a AmBev não falir, não fali...
# 3      Fiz cadastro com CNPJ na ambev, tem polar lá n...
# 4      Drinking a Chopp Brahma by AmBev at @bar_brahm...
# ...                                                  ...
# 19995  Crlh tinha que arrumar um patrício com a Ambev...
# 19996  Reposted from esquerdavalente (get_regrann)  -...
# 19997             Só queria ser parente do dono da Ambev
# 19998  Drinking an Antarctica Sub Zero by AmBev @ Luz...
# 19999  Ultimo encontro do curso FIA/AMBEV - Excelênci...
#
# [20000 rows x 2 columns]

# %%
df.to_csv("ambev.csv")

# %%
search_hoegaarden = "'Hoegaarden' near:'Brazil' since:2019-01-01 until:2021-11-22"

# the scraped tweets, this is a generator
scraped_tweets_hoegaarden = sntwitter.TwitterSearchScraper(search_hoegaarden).get_items()


# slicing the generator to keep only the first 100 tweets
sliced_scraped_tweets_hoegaarden = itertools.islice(scraped_tweets_hoegaarden, 100)

# convert to a DataFrame and keep only relevant columns
df_hoegarden = pd.DataFrame(sliced_scraped_tweets_hoegaarden)[['date', 'content']]

# %%
df_hoegarden
# Out:
#                         date  \
# 0  2021-10-15 14:08:23+00:00
# 1  2021-10-08 13:52:03+00:00
# 2  2021-10-02 15:35:02+00:00
# 3  2021-09-29 20:52:54+00:00
# 4  2021-09-12 00:48:13+00:00
# ..                       ...
# 95 2020-07-30 22:57:35+00:00
# 96 2020-07-28 23:55:37+00:00
# 97 2020-07-25 07:07:40+00:00
# 98 2020-07-22 15:39:50+00:00
# 99 2020-07-22 03:25:42+00:00
#
#                                               content
# 0   @claudierla aaaa nunca tinha visto hoegaarden ...
# 1   Simplesmente do lado da rodoviária um lugar ve...
# 2   @Ambev , porque ainda não existe Hoegaarden li...
# 3   comemorando aqui no Hoegaarden Green House de ...
# 4   vontadona de comer um torresmo e tomar uma hoe...
# ..                                                ...
# 95  Como eu queria agora uma breja witbier ..de pr...
# 96  Drinking a Hoegaarden Rosée by @hoegaarden @ E...
# 97  @J_blueberry6 o mais caro vinho jamais será me...
# 98  Essa taça fez sucesso no final de semana... Qu...
# 99  height            : 6’2”\nshoe size      : 10\...
#
# [100 rows x 2 columns]

# %%
df_hoegarden.to_csv("hoegaarden.csv")

# %% [markdown]
# ----
